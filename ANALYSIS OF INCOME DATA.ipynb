# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

income = pd.read_csv("INCOME_DATA.CSV")
income
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
income.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
income.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %%
"THE SHAPE OF DATA SET IS" , income.shape
# Out:
# ('THE SHAPE OF DATA SET IS', (48842, 15))

# %%
"THE NUMBER OF ROWS IN DATA SET IS" , income.shape[0]
# Out:
# ('THE NUMBER OF ROWS IN DATA SET IS', 48842)

# %%
"THE NUMBER OF COLUMNS IN DATA SET IS" , income.shape[1]
# Out:
# ('THE NUMBER OF COLUMNS IN DATA SET IS', 15)

# %%
"THE INFORMATION OF DATASET IS GIVEN ABOVE" , income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  salary           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB
# ...

# %%
# FETCH 50% RANDOM SAMPLES FROM THE DATA SET .
income.sample (frac=0.50)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 20520   24           Private  116934  Some-college               10
# 33335   60  Self-emp-not-inc  205246       HS-grad                9
# 21258   55           Private  414994       HS-grad                9
# 16401   21           Private  199915  Some-college               10
# 11746   47           Private  199058  Some-college               10
# ...    ...               ...     ...           ...              ...
# 12385   32           Private  340917       Masters               14
# 26971   44           Private  190532       Masters               14
# 11264   19           Private  163885       HS-grad                9
# 39605   39           Private  103925     Bachelors               13
# 4221    22                 ?  117789  Some-college               10
#
#            marital-status         occupation   relationship   race  gender  \
# ...

# %%
# FETCH 10% RANDOM SAMPLES FROM THE DATA SET .
income.sample (frac=0.10)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 30569   51  Self-emp-not-inc  111939       HS-grad                9
# 17234   18           Private  177722       HS-grad                9
# 24823   35         State-gov  349066       HS-grad                9
# 36497   45       Federal-gov   81487  Some-college               10
# 39485   20           Private  148509       HS-grad                9
# ...    ...               ...     ...           ...              ...
# 1955    27                 ?  119851  Some-college               10
# 46859   29           Private  444304     Bachelors               13
# 18879   41           Private  183203       HS-grad                9
# 14787   36         Local-gov  152021          11th                7
# 47403   50           Private   28952  Some-college               10
#
#            marital-status         occupation   relationship  \
# 30569  Married-civ-spouse   Transport-moving        Husband
# ...

# %%
# FETCH 5% RANDOM SAMPLES FROM THE DATA SET .
income.sample (frac=0.05)
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 44645   54    Private  175594       HS-grad                9
# 18716   44  Local-gov  210527  Some-college               10
# 12616   47          ?  308499       HS-grad                9
# 34053   46    Private  318331       HS-grad                9
# 1828    22          ?  303579  Some-college               10
# ...    ...        ...     ...           ...              ...
# 20762   25    Private  168403     Bachelors               13
# 39850   29    Private  244721     Bachelors               13
# 7076    26    Private   40915     Bachelors               13
# 27599   60    Private   80574       HS-grad                9
# 23539   42  State-gov  102343   Prof-school               15
#
#            marital-status         occupation   relationship  \
# 44645  Married-civ-spouse       Craft-repair        Husband
# 18716       Never-married      Other-service      Unmarried
# ...

# %%
# FETCH 5% RANDOM SAMPLES FROM THE DATA SET .
income.sample (frac=0.05 , random_state=10 )
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 28113   34           Private  339142       HS-grad                9
# 40486   69           Private  130413     Bachelors               13
# 45549   26         Local-gov   72594  Some-college               10
# 3173    57         Local-gov  212303       Masters               14
# 46828   18           Private  137646          11th                7
# ...    ...               ...     ...           ...              ...
# 21890   35           Private  148903       HS-grad                9
# 7177    23           Private   60668  Some-college               10
# 14711   39         Local-gov  167571       HS-grad                9
# 3556    41           Private  123306  Some-college               10
# 29623   47  Self-emp-not-inc   39986     Bachelors               13
#
#            marital-status         occupation   relationship   race  gender  \
# ...

# %%
# FETCH 5% RANDOM SAMPLES FROM THE DATA SET .
income.sample (frac=0.05 , random_state=20 )
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 21601   28                 ?  230704       HS-grad                9
# 45922   46           Private  158656    Assoc-acdm               12
# 29979   37           Private   69251  Some-college               10
# 37053   71           Private  193530          11th                7
# 18094   22           Private  311764          11th                7
# ...    ...               ...     ...           ...              ...
# 26875   45           Private  117409  Some-college               10
# 48180   59           Private  159008  Some-college               10
# 14290   35           Private  188069     Bachelors               13
# 31497   25  Self-emp-not-inc  463667       HS-grad                9
# 25507   42           Private  152568       HS-grad                9
#
#            marital-status        occupation   relationship  \
# 21601       Never-married                 ?  Not-in-family
# ...

# %%
# FETCH 5% RANDOM SAMPLES FROM THE DATA SET .
df = income.sample (frac=0.05 , random_state=20 )
df
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 21601   28                 ?  230704       HS-grad                9
# 45922   46           Private  158656    Assoc-acdm               12
# 29979   37           Private   69251  Some-college               10
# 37053   71           Private  193530          11th                7
# 18094   22           Private  311764          11th                7
# ...    ...               ...     ...           ...              ...
# 26875   45           Private  117409  Some-college               10
# 48180   59           Private  159008  Some-college               10
# 14290   35           Private  188069     Bachelors               13
# 31497   25  Self-emp-not-inc  463667       HS-grad                9
# 25507   42           Private  152568       HS-grad                9
#
#            marital-status        occupation   relationship  \
# 21601       Never-married                 ?  Not-in-family
# ...

# %%
# CHECK NULL VALUES IN THE DATA SET .
income.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
# CHECK NULL VALUES IN THE DATA SET COLUMN WISE .
income.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# salary             0
# dtype: int64

# %%
# CHECK NULL VALUES IN THE DATA SET ROW WISE .
income.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
# CHECK NULL VALUES IN THE DATA SET USING SEABORN .
import seaborn as sns
sns.heatmap ( income.isnull() )
# Out:
# <Axes: >

# %%
# REPLACE ALL "?" WITH "NaN" .
income.tail(20)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 48822   41                 ?  202822       HS-grad                9
# 48823   72                 ?  129912       HS-grad                9
# 48824   45         Local-gov  119199    Assoc-acdm               12
# 48825   31           Private  199655       Masters               14
# 48826   39         Local-gov  111499    Assoc-acdm               12
# 48827   37           Private  198216    Assoc-acdm               12
# 48828   43           Private  260761       HS-grad                9
# 48829   65  Self-emp-not-inc   99359   Prof-school               15
# 48830   43         State-gov  255835  Some-college               10
# 48831   43  Self-emp-not-inc   27242  Some-college               10
# 48832   32           Private   34066          10th                6
# 48833   43           Private   84661     Assoc-voc               11
# 48834   32           Private  116138       Masters               14
# ...

# %%
income.isin (["?"])
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False       True   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
income.isin (["?"]) .sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# salary                0
# dtype: int64

# %%
income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
import numpy as np
income = income.replace ( "?" , np.nan )
income
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
income.isin (["?"]) .sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# salary             0
# dtype: int64

# %%
# CHECK THE NULL VALUES .
income.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# salary                0
# dtype: int64

# %%
# CHECK THE NULL VALUES USING SEABORN .
import seaborn as sns
sns.heatmap ( income.isnull() )
# Out:
# <Axes: >

# %%
# DROP ALL THE MISSING VALUES .
missing_values = income.isnull().sum() * 100 / len(income)
missing_values
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# salary             0.000000
# dtype: float64

# %%
income.shape
# Out:
# (48842, 15)

# %%
income.dropna ( how="any" , inplace=True )
income.shape
# Out:
# (45222, 15)

# %%
# CHECK FOR DUPLICATE DATA .
dup_data = income.duplicated().any()
"ANY DUPLICATE VALUES IN DATA" , dup_data
# Out:
# ('ANY DUPLICATE VALUES IN DATA', True)

# %%
# DROP THE DUPLICATE DATA .
income = income.drop_duplicates()
income.shape
# Out:
# (45175, 15)

# %%
# FIND THE OVERALL STATISTICS OF THE DATA SET .
income.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
# FIND THE OVERALL STATISTICS OF ALL THE COLUMNS OF THE DATA SET .
income.describe(include="all")
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45175.000000     45175  4.517500e+04     45175     45175.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14770              NaN
# mean       38.556170       NaN  1.897388e+05       NaN        10.119314
# std        13.215349       NaN  1.056524e+05       NaN         2.551740
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173925e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %%
# FIND ALL COLUMNS OF THE DATA SET ,
income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
# DISPLAY UNIQUE VALUES OF COLUMN "education" .
income["education"].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
# DISPLAY UNIQUE VALUES OF COLUMN "educational-num" .
income["educational-num"].unique()
# Out:
# array([ 7,  9, 12, 10,  6, 15,  4, 13, 14,  3, 11,  5, 16,  8,  2,  1],
#       dtype=int64)

# %%
income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
# DROP THE COLUMNS : "educational-num" , "capital-gain" , "apital-loss" .
income = income.drop ( [ "educational-num" , "capital-gain" , "capital-loss" ] , axis=1 )
income
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %%
income.shape
# Out:
# (45175, 12)

# %%
income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'salary'],
#       dtype='object')

# %%
# FIND THE DISTRIBUTION OF "age" COLUMN .
income["age"].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
# FIRST METHOD 
import matplotlib.pyplot as plt
plt.hist ( income["age"] )
# Out:
# (array([7288., 8215., 8701., 8802., 5713., 3609., 2000.,  579.,  192.,
#           76.]),
#  array([17. , 24.3, 31.6, 38.9, 46.2, 53.5, 60.8, 68.1, 75.4, 82.7, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
# SECOND METHOD 
income["age"].hist()
# Out:
# <Axes: >

# %%
# FIND THE NUMBER OF PERSONS HAVING "age" BETWEEN 17 TO 48 WITHOUT USING BETWEEN METHOD .
( income["age"] >= 17 ) & ( income["age"] <= 48 )
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 5         True
#          ...
# 48837     True
# 48838     True
# 48839    False
# 48840     True
# 48841    False
# Name: age, Length: 45175, dtype: bool

# %%
income [ ( income["age"] >= 17 ) & ( income["age"] <= 48 ) ]
# Out:
#        age  workclass  fnlwgt     education      marital-status  \
# 0       25    Private  226802          11th       Never-married
# 1       38    Private   89814       HS-grad  Married-civ-spouse
# 2       28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44    Private  160323  Some-college  Married-civ-spouse
# 5       34    Private  198693          10th       Never-married
# ...    ...        ...     ...           ...                 ...
# 48834   32    Private  116138       Masters       Never-married
# 48836   22    Private  310152  Some-college       Never-married
# 48837   27    Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40    Private  154374       HS-grad  Married-civ-spouse
# 48840   22    Private  201490       HS-grad       Never-married
#
#               occupation   relationship                race  gender  \
# 0      Machine-op-inspct      Own-child               Black    Male
# ...

# %%
sum ( ( income["age"] >= 17 ) & ( income["age"] <= 48 ) )
# Out:
# 34858

# %%
# FIND THE NUMBER OF PERSONS HAVING "age" BETWEEN 17 TO 48 WITH USING BETWEEN METHOD .
income["age"].between(17,48)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 5         True
#          ...
# 48837     True
# 48838     True
# 48839    False
# 48840     True
# 48841    False
# Name: age, Length: 45175, dtype: bool

# %%
income [ income["age"].between(17,48) ]
# Out:
#        age  workclass  fnlwgt     education      marital-status  \
# 0       25    Private  226802          11th       Never-married
# 1       38    Private   89814       HS-grad  Married-civ-spouse
# 2       28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44    Private  160323  Some-college  Married-civ-spouse
# 5       34    Private  198693          10th       Never-married
# ...    ...        ...     ...           ...                 ...
# 48834   32    Private  116138       Masters       Never-married
# 48836   22    Private  310152  Some-college       Never-married
# 48837   27    Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40    Private  154374       HS-grad  Married-civ-spouse
# 48840   22    Private  201490       HS-grad       Never-married
#
#               occupation   relationship                race  gender  \
# 0      Machine-op-inspct      Own-child               Black    Male
# ...

# %%
sum ( income["age"].between(17,48) )
# Out:
# 34858

# %%
income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'salary'],
#       dtype='object')

# %%
# FIND THE DISTRIBUTION OF "workclass" COLUMN .
income["workclass"].describe()
# Out:
# count       45175
# unique          7
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %%
# FIRST METHOD
import matplotlib.pyplot as plt
plt.hist ( income["workclass"] )
# Out:
# (array([3.3262e+04, 3.1000e+03, 0.0000e+00, 3.7950e+03, 0.0000e+00,
#         1.4060e+03, 1.9460e+03, 0.0000e+00, 1.6450e+03, 2.1000e+01]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
# SECOND METHOD 
income["workclass"].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.figure ( figsize=(10,10) )
income["workclass"].hist()
# Out:
# <Axes: >

# %%
# FIND HOW MANY PERSONS HAVING "Bachelors" OR "Masters" DEGREE .
income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'salary'],
#       dtype='object')

# %%
# FIRST METHOD 
income["education"].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
bac = income["education"] == "Bachelors" 
bac
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 5        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Name: education, Length: 45175, dtype: bool

# %%
mas = income["education"] == "Masters" 
mas
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 5        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Name: education, Length: 45175, dtype: bool

# %%
bac | mas
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 5        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Name: education, Length: 45175, dtype: bool

# %%
income [ bac | mas ]
# Out:
#        age    workclass  fnlwgt  education      marital-status  \
# 11      36  Federal-gov  212465  Bachelors  Married-civ-spouse
# 15      43      Private  346189    Masters  Married-civ-spouse
# 20      34      Private  107914  Bachelors  Married-civ-spouse
# 23      25      Private  220931  Bachelors       Never-married
# 24      25      Private  205947  Bachelors  Married-civ-spouse
# ...    ...          ...     ...        ...                 ...
# 48817   34      Private  160216  Bachelors       Never-married
# 48819   38      Private  139180  Bachelors            Divorced
# 48825   31      Private  199655    Masters            Divorced
# 48834   32      Private  116138    Masters       Never-married
# 48835   53      Private  321865    Masters  Married-civ-spouse
#
#             occupation   relationship                race  gender  \
# 11        Adm-clerical        Husband               White    Male
# 15     Exec-managerial        Husband               White    Male
# ...

# %%
len ( income [ bac | mas ] )
# Out:
# 10072

# %%
# SECOND METHOD 
income["education"]. isin ([ "Bachelors" , "Masters" ])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 5        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Name: education, Length: 45175, dtype: bool

# %%
income [ income["education"]. isin ([ "Bachelors" , "Masters" ]) ]
# Out:
#        age    workclass  fnlwgt  education      marital-status  \
# 11      36  Federal-gov  212465  Bachelors  Married-civ-spouse
# 15      43      Private  346189    Masters  Married-civ-spouse
# 20      34      Private  107914  Bachelors  Married-civ-spouse
# 23      25      Private  220931  Bachelors       Never-married
# 24      25      Private  205947  Bachelors  Married-civ-spouse
# ...    ...          ...     ...        ...                 ...
# 48817   34      Private  160216  Bachelors       Never-married
# 48819   38      Private  139180  Bachelors            Divorced
# 48825   31      Private  199655    Masters            Divorced
# 48834   32      Private  116138    Masters       Never-married
# 48835   53      Private  321865    Masters  Married-civ-spouse
#
#             occupation   relationship                race  gender  \
# 11        Adm-clerical        Husband               White    Male
# 15     Exec-managerial        Husband               White    Male
# ...

# %%
sum ( income["education"]. isin ([ "Bachelors" , "Masters" ]) )
# Out:
# 10072

# %%
income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'salary'],
#       dtype='object')

# %%
# FIND RELATIONSHIP BETWEEN "age" COLUMN AND "salary" COLUMN USING SEABORN .
import seaborn as sns
sns.boxplot ( x="salary" , y="age" , data=income )
# Out:
# <Axes: xlabel='salary', ylabel='age'>

# %%
income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'salary'],
#       dtype='object')

# %%
# REPLACE SALARY VALUE "<=50K" AND ">50K" WITH 0.0 AND 1.0 RESPECTIVELY .
income["salary"].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
income["salary"].value_counts()
# Out:
# <=50K    33973
# >50K     11202
# Name: salary, dtype: int64

# %%
# FIRST METHOD 
def salary_data(sal):
    
    if sal == "<=50K":
        return 0
    else:
        return 1
    
income["encoded-salary"] = income["salary"].apply(salary_data) 
income.head()
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 5   34    Private  198693          10th       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country salary  encoded-salary
# 0  United-States  <=50K               0
# 1  United-States  <=50K               0
# 2  United-States   >50K               1
# 3  United-States   >50K               1
# ...

# %%
# SECOND METHOD
income.replace ( to_replace=["<=50K",">50K"] , value=[0,1] , inplace=True )
income.head()
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 5   34    Private  198693          10th       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country  salary  encoded-salary
# 0  United-States       0               0
# 1  United-States       0               0
# 2  United-States       1               1
# ...

# %%
income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'salary', 'encoded-salary'],
#       dtype='object')

# %%
# FIND THE "workclass" WHICH IS GETTING THE HIGHEST "salary" .
income.groupby("workclass")

# %%
income.groupby("workclass") ['salary'] .mean()
# Out:
# workclass
# Federal-gov         0.390469
# Local-gov           0.295161
# Private             0.217816
# Self-emp-inc        0.554407
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Without-pay         0.095238
# Name: salary, dtype: float64

# %%
income.groupby("workclass") ['salary'] .mean() .sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554407
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.279051
# State-gov           0.267215
# Private             0.217816
# Without-pay         0.095238
# Name: salary, dtype: float64

# %%
income.groupby("workclass") ['salary'] .mean() .sort_values(ascending=False) .head(1)
# Out:
# workclass
# Self-emp-inc    0.554407
# Name: salary, dtype: float64

# %%
income.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'salary', 'encoded-salary'],
#       dtype='object')

# %%
# WHICH "gender" HAS BETTER CHANCE TO GET "salary" >=50K .
income.groupby("gender") ["salary"]

# %%
income.groupby("gender") ["salary"] .mean()
# Out:
# gender
# Female    0.113692
# Male      0.312609
# Name: salary, dtype: float64

# %%
income.groupby("gender") ["salary"] .mean() .sort_values(ascending=False)
# Out:
# gender
# Male      0.312609
# Female    0.113692
# Name: salary, dtype: float64

# %%
income.groupby("gender") ["salary"] .mean() .sort_values(ascending=False) .head(1)
# Out:
# gender
# Male    0.312609
# Name: salary, dtype: float64

# %%
"THE INFORMATION OF THE DATA SET" , income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  object
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  salary          45175 non-null  int64
#  12  encoded-salary  45175 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 4.8+ MB
# ('THE INFORMATION OF THE DATA SET', None)

# %%
# CONVERT DATA TYPE OF "workclass" COLUMN FROM "object" TO "category" .
income["workclass"] = income["workclass"].astype("category")
"THE INFORMATION OF THE DATA SET" , income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  category
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  salary          45175 non-null  int64
#  12  encoded-salary  45175 non-null  int64
# dtypes: category(1), int64(5), object(7)
# memory usage: 4.5+ MB
# ('THE INFORMATION OF THE DATA SET', None)
